# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaKCodes/OpenMScThesisInNeuroPixelProbeDataAnalysis/blob/main/SearchApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ONE-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ONE-api
#   Downloading ONE_api-1.16.0-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 3.2 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ONE-api) (6.0)
# Collecting boto3
#   Downloading boto3-1.24.87-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 45.8 MB/s
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.7/dist-packages (from ONE-api) (1.3.5)
# Requirement already satisfied: tqdm>=4.32.1 in /usr/local/lib/python3.7/dist-packages (from ONE-api) (4.64.1)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from ONE-api) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from ONE-api) (21.3)
# Collecting flake8>=3.7.8
#   Downloading flake8-5.0.4-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 319 kB/s
# Collecting iblutil>=1.1.0
#   Downloading iblutil-1.3.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from ONE-api) (2.23.0)
# Collecting mccabe<0.8.0,>=0.7.0
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting importlib-metadata<4.3,>=1.1.0
#   Downloading importlib_metadata-4.2.0-py3-none-any.whl (16 kB)
# Collecting pyflakes<2.6.0,>=2.5.0
#   Downloading pyflakes-2.5.0-py2.py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 1.3 MB/s
# Collecting pycodestyle<2.10.0,>=2.9.0
#   Downloading pycodestyle-2.9.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 132 kB/s
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from iblutil>=1.1.0->ONE-api) (0.56.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from iblutil>=1.1.0->ONE-api) (6.0.1)
# Collecting colorlog>=6.0.0
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<4.3,>=1.1.0->flake8>=3.7.8->ONE-api) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<4.3,>=1.1.0->flake8>=3.7.8->ONE-api) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.4->ONE-api) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.4->ONE-api) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.4->ONE-api) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->ONE-api) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->ONE-api) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->ONE-api) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->ONE-api) (2.10)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.28.0,>=1.27.87
#   Downloading botocore-1.27.87-py3-none-any.whl (9.2 MB)
#      |████████████████████████████████| 9.2 MB 64.2 MB/s
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.1 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 57.0 MB/s
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->iblutil>=1.1.0->ONE-api) (0.39.1)
# Requirement already satisfied: setuptools<60 in /usr/local/lib/python3.7/dist-packages (from numba->iblutil>=1.1.0->ONE-api) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->ONE-api) (3.0.9)
# Installing collected packages: urllib3, jmespath, pyflakes, pycodestyle, mccabe, importlib-metadata, botocore, s3transfer, flake8, colorlog, iblutil, boto3, ONE-api
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.12.0
#     Uninstalling importlib-metadata-4.12.0:
#       Successfully uninstalled importlib-metadata-4.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.4.1 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# gym 0.25.2 requires importlib-metadata>=4.8.0; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# Successfully installed ONE-api-1.16.0 boto3-1.24.87 botocore-1.27.87 colorlog-6.7.0 flake8-5.0.4 iblutil-1.3.1 importlib-metadata-4.2.0 jmespath-1.0.1 mccabe-0.7.0 pycodestyle-2.9.1 pyflakes-2.5.0 s3transfer-0.6.0 urllib3-1.25.11

# %%
from one.api import ONE
one = ONE(base_url='https://openalyx.internationalbrainlab.org', password='international', silent=True)
one.list_datasets()
# Out:
# ['alf/_ibl_trials.table.pqt',
#  'alf/_ibl_trials.repNum.npy',
#  'alf/_ibl_trials.feedbackType.npy',
#  'alf/_ibl_trials.response_times.npy',
#  'alf/_ibl_trials.contrastLeft.npy',
#  'alf/_ibl_trials.feedback_times.npy',
#  'alf/_ibl_trials.choice.npy',
#  'alf/_ibl_trials.probabilityLeft.npy',
#  'alf/_ibl_trials.stimOn_times.npy',
#  'alf/_ibl_trials.intervals.npy',
#  'alf/_ibl_trials.contrastRight.npy',
#  'alf/_ibl_trials.goCue_times.npy',
#  'raw_behavior_data/_iblrig_ambientSensorData.raw.jsonable',
#  'alf/probe00/pykilosort/channels.rawInd.npy',
#  'alf/probe00/pykilosort/channels.localCoordinates.npy',
#  'raw_video_data/_iblrig_leftCamera.raw.mp4',
#  'alf/_ibl_rightCamera.times.npy',
#  'alf/_ibl_rightCamera.dlc.pqt',
#  'alf/_ibl_trials.itiDuration.npy',
#  'alf/probe00/pykilosort/spikes.depths.npy',
#  'alf/probe00/pykilosort/spikes.samples.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.ap.cbin',
#  'alf/probe00/pykilosort/templates.waveforms.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.ap.ch',
#  'alf/probe00/pykilosort/channels.mlapdv.npy',
#  'alf/probe00/pykilosort/templates.amps.npy',
#  'raw_ephys_data/_spikeglx_sync.polarities.npy',
#  'alf/probe00/pykilosort/templates.waveformsChannels.npy',
#  'alf/leftCamera.ROIMotionEnergy.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.lf.meta',
#  'raw_ephys_data/probe00/_spikeglx_sync.channels.probe00.npy',
#  'alf/probe00/pykilosort/clusters.waveforms.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.wiring.json',
#  'raw_ephys_data/probe00/_iblqc_ephysTimeRmsAP.rms.npy',
#  'raw_ephys_data/probe00/_iblqc_ephysTimeRmsLF.rms.npy',
#  'alf/_ibl_wheelMoves.intervals.npy',
#  'raw_ephys_data/_spikeglx_ephysData_g0_t0.nidq.meta',
#  'alf/probe00/pykilosort/drift.um.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.lf.ch',
#  'alf/probe00/electrodeSites.brainLocationIds_ccf_2017.npy',
#  'alf/probe00/pykilosort/spikes.templates.npy',
#  'alf/probe00/pykilosort/clusters.channels.npy',
#  'alf/probe00/electrodeSites.mlapdv.npy',
#  'alf/_ibl_leftCamera.times.npy',
#  'alf/_ibl_wheel.timestamps.npy',
#  'alf/probe00/pykilosort/_ibl_log.info_pykilosort.log',
#  'raw_ephys_data/_spikeglx_ephysData_g0_t0.nidq.wiring.json',
#  'alf/probe00/pykilosort/clusters.metrics.pqt',
#  'raw_ephys_data/probe00/_iblqc_ephysSpectralDensityAP.power.npy',
#  'alf/probe00/pykilosort/spikes.amps.npy',
#  'alf/probe00/pykilosort/spikes.clusters.npy',
#  'alf/probe00/pykilosort/_phy_spikes_subset.spikes.npy',
#  'alf/probe00/pykilosort/_phy_spikes_subset.waveforms.npy',
#  'alf/_ibl_leftCamera.dlc.pqt',
#  'alf/probe00/pykilosort/drift.times.npy',
#  'alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy',
#  'alf/leftROIMotionEnergy.position.npy',
#  'alf/probe00/electrodeSites.localCoordinates.npy',
#  'raw_ephys_data/probe00/_iblqc_ephysChannels.apRMS.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.sync.npy',
#  'raw_video_data/_iblrig_rightCamera.raw.mp4',
#  'raw_ephys_data/probe00/_iblqc_ephysSpectralDensityLF.freqs.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.ap.meta',
#  'alf/_ibl_wheel.position.npy',
#  'alf/probe00/pykilosort/clusters.peakToTrough.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.lf.cbin',
#  'raw_ephys_data/probe00/_iblqc_ephysChannels.rawSpikeRates.npy',
#  'alf/probe00/pykilosort/clusters.depths.npy',
#  'alf/bodyROIMotionEnergy.position.npy',
#  'alf/bodyCamera.ROIMotionEnergy.npy',
#  'raw_ephys_data/_spikeglx_sync.channels.npy',
#  'raw_ephys_data/probe00/_iblqc_ephysChannels.labels.npy',
#  'alf/probe00/pykilosort/_phy_spikes_subset.channels.npy',
#  'alf/probe00/pykilosort/clusters.amps.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.timestamps.npy',
#  'alf/probe00/pykilosort/clusters.uuids.csv',
#  'alf/rightCamera.ROIMotionEnergy.npy',
#  'raw_ephys_data/probe00/_spikeglx_sync.times.probe00.npy',
#  'alf/probe00/pykilosort/spikes.times.npy',
#  'alf/rightROIMotionEnergy.position.npy',
#  'raw_ephys_data/probe00/_iblqc_ephysSpectralDensityLF.power.npy',
#  'alf/_ibl_bodyCamera.dlc.pqt',
#  'raw_ephys_data/probe00/_spikeglx_sync.polarities.probe00.npy',
#  'alf/probe00/pykilosort/drift_depths.um.npy',
#  'alf/_ibl_wheelMoves.peakAmplitude.npy',
#  'alf/probes.description.json',
#  'raw_ephys_data/probe00/_iblqc_ephysTimeRmsLF.timestamps.npy',
#  'alf/_ibl_bodyCamera.times.npy',
#  'alf/probe00/pykilosort/_kilosort_whitening.matrix.npy',
#  'raw_video_data/_iblrig_bodyCamera.raw.mp4',
#  'alf/probe00/pykilosort/clusters.waveformsChannels.npy',
#  'raw_ephys_data/_spikeglx_sync.times.npy',
#  'raw_ephys_data/probe00/_iblqc_ephysTimeRmsAP.timestamps.npy',
#  'raw_ephys_data/probe00/_iblqc_ephysSpectralDensityAP.freqs.npy',
#  'alf/_ibl_trials.goCueTrigger_times.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec.ap.ch',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec.ap.cbin',
#  'alf/_ibl_trials.stimOff_times.npy',
#  'alf/_ibl_leftCamera.features.pqt',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec.sync.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec.timestamps.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec.lf.meta',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec.wiring.json',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec.ap.meta',
#  'alf/_ibl_rightCamera.features.pqt',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec.lf.cbin',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec.lf.ch',
#  'alf/licks.times.npy',
#  'raw_ephys_data/_spikeglx_ephysData_g0_t0.nidq.cbin',
#  'raw_ephys_data/_spikeglx_ephysData_g0_t0.nidq.ch',
#  'alf/probe01/pykilosort/templates.waveforms.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.wiring.json',
#  'alf/probe01/electrodeSites.brainLocationIds_ccf_2017.npy',
#  'alf/probe01/pykilosort/spikes.amps.npy',
#  'alf/probe01/pykilosort/clusters.amps.npy',
#  'raw_ephys_data/probe01/_iblqc_ephysTimeRmsAP.timestamps.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.lf.meta',
#  'alf/probe01/pykilosort/spikes.clusters.npy',
#  'alf/probe01/pykilosort/channels.rawInd.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.ap.ch',
#  'alf/probe01/pykilosort/clusters.waveforms.npy',
#  'alf/probe01/pykilosort/spikes.depths.npy',
#  'raw_ephys_data/probe01/_iblqc_ephysSpectralDensityAP.power.npy',
#  'raw_ephys_data/probe01/_spikeglx_sync.polarities.probe01.npy',
#  'raw_ephys_data/probe01/_iblqc_ephysSpectralDensityLF.power.npy',
#  'alf/probe01/pykilosort/spikes.times.npy',
#  'raw_ephys_data/probe01/_iblqc_ephysTimeRmsLF.rms.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.lf.ch',
#  'alf/probe01/pykilosort/drift.times.npy',
#  'alf/probe01/pykilosort/_phy_spikes_subset.spikes.npy',
#  'alf/probe01/pykilosort/_phy_spikes_subset.channels.npy',
#  'alf/probe01/pykilosort/channels.brainLocationIds_ccf_2017.npy',
#  'alf/probe01/pykilosort/clusters.depths.npy',
#  'alf/probe01/pykilosort/_kilosort_whitening.matrix.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.timestamps.npy',
#  'alf/probe01/pykilosort/channels.mlapdv.npy',
#  'alf/probe01/pykilosort/clusters.channels.npy',
#  'raw_ephys_data/probe01/_spikeglx_sync.channels.probe01.npy',
#  'alf/probe01/electrodeSites.mlapdv.npy',
#  'alf/probe01/pykilosort/spikes.templates.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.ap.cbin',
#  'alf/probe01/pykilosort/drift.um.npy',
#  'alf/probe01/pykilosort/templates.waveformsChannels.npy',
#  'raw_ephys_data/probe01/_iblqc_ephysTimeRmsLF.timestamps.npy',
#  'raw_ephys_data/probe01/_iblqc_ephysTimeRmsAP.rms.npy',
#  'alf/probe01/pykilosort/templates.amps.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.lf.cbin',
#  'alf/probe01/pykilosort/clusters.uuids.csv',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.sync.npy',
#  'alf/probe01/pykilosort/_phy_spikes_subset.waveforms.npy',
#  'alf/probe01/pykilosort/clusters.peakToTrough.npy',
#  'alf/probe01/pykilosort/channels.localCoordinates.npy',
#  'alf/probe01/pykilosort/spikes.samples.npy',
#  'raw_ephys_data/probe01/_iblqc_ephysSpectralDensityLF.freqs.npy',
#  'raw_ephys_data/probe01/_spikeglx_sync.times.probe01.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.ap.meta',
#  'raw_ephys_data/probe01/_iblqc_ephysSpectralDensityAP.freqs.npy',
#  'alf/probe01/electrodeSites.localCoordinates.npy',
#  'alf/probe01/pykilosort/clusters.metrics.pqt',
#  'alf/probe01/pykilosort/drift_depths.um.npy',
#  'alf/probe01/pykilosort/_ibl_log.info_pykilosort.log',
#  'alf/probe01/pykilosort/clusters.waveformsChannels.npy',
#  'alf/_ibl_trials.intervals_bpod.npy',
#  'raw_ephys_data/probe01/_iblqc_ephysChannels.rawSpikeRates.npy',
#  'raw_ephys_data/probe01/_iblqc_ephysChannels.apRMS.npy',
#  'raw_ephys_data/probe01/_iblqc_ephysChannels.labels.npy',
#  'alf/probe00/clusters.peakToTrough.npy',
#  'alf/probe00/templates.waveformsChannels.npy',
#  'alf/probe00/clusters.brainLocationIds_ccf_2017.npy',
#  'alf/probe00/channels.rawInd.npy',
#  'raw_ephys_data/probe00/#2021-12-10#/_iblqc_ephysTimeRmsAP.rms.npy',
#  'alf/probe00/templates.waveforms.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_probe00_g0/_spikeglx_sync.channels._spikeglx_ephysData_probe00_g0.npy',
#  'alf/#2022-01-29#/rightROIMotionEnergy.position.npy',
#  'alf/probe00/clusters.depths.npy',
#  'alf/probe00/channels.brainLocationIds_ccf_2017.npy',
#  'alf/#2022-01-29#/leftCamera.ROIMotionEnergy.npy',
#  'alf/probe00/channels.localCoordinates.npy',
#  'alf/probe00/clusters.waveformsChannels.npy',
#  'alf/#2022-01-29#/rightCamera.ROIMotionEnergy.npy',
#  'alf/probe00/clusters.brainLocationAcronyms_ccf_2017.npy',
#  'alf/probe00/clusters.uuids.csv',
#  'alf/#2022-01-29#/_ibl_leftCamera.dlc.pqt',
#  'alf/probe00/_phy_spikes_subset.waveforms.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_probe00_g0/_spikeglx_sync.times._spikeglx_ephysData_probe00_g0.npy',
#  'alf/probe00/spikes.templates.npy',
#  'alf/probe00/_phy_spikes_subset.channels.npy',
#  'alf/probe00/clusters.mlapdv.npy',
#  'alf/probe00/_phy_spikes_subset.spikes.npy',
#  'alf/probe00/spikes.samples.npy',
#  'alf/probe00/clusters.amps.npy',
#  'alf/probe00/clusters.metrics.pqt',
#  'alf/probe00/clusters.waveforms.npy',
#  'alf/probe00/channels.mlapdv.npy',
#  'alf/probe00/spikes.times.npy',
#  'alf/probe00/spikes.clusters.npy',
#  'alf/#2022-01-29#/_ibl_rightCamera.dlc.pqt',
#  'alf/probe00/templates.amps.npy',
#  'raw_ephys_data/probe00/#2021-12-10#/_iblqc_ephysTimeRmsAP.timestamps.npy',
#  'alf/probe00/spikes.depths.npy',
#  'alf/#2022-01-29#/bodyCamera.ROIMotionEnergy.npy',
#  'alf/#2022-01-29#/bodyROIMotionEnergy.position.npy',
#  'alf/#2022-01-29#/leftROIMotionEnergy.position.npy',
#  'alf/#2022-01-29#/_ibl_bodyCamera.dlc.pqt',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_probe00_g0/_spikeglx_sync.polarities._spikeglx_ephysData_probe00_g0.npy',
#  'alf/probe00/spikes.amps.npy',
#  'alf/probe00/clusters.channels.npy',
#  'alf/probe00/_kilosort_whitening.matrix.npy',
#  'alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy',
#  'alf/#2022-01-31#/_ibl_leftCamera.dlc.pqt',
#  'alf/#2022-01-31#/bodyCamera.ROIMotionEnergy.npy',
#  'alf/#2022-01-31#/_ibl_bodyCamera.dlc.pqt',
#  'alf/#2022-01-31#/rightROIMotionEnergy.position.npy',
#  'alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt',
#  'alf/#2022-01-31#/leftCamera.ROIMotionEnergy.npy',
#  'alf/#2022-01-31#/leftROIMotionEnergy.position.npy',
#  'alf/#2022-01-31#/bodyROIMotionEnergy.position.npy',
#  'alf/_ibl_wheel.times.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g2_t0.imec.timestamps.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g2_t0.imec.lf.meta',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g2_t0.imec.ap.ch',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g2_t0.imec.sync.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g2_t0.imec.lf.ch',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g2_t0.imec.ap.cbin',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g2_t0.imec.lf.cbin',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g2_t0.imec.ap.meta',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g2_t0.imec.wiring.json',
#  'alf/probe01/spikes.amps.npy',
#  'alf/probe01/clusters.amps.npy',
#  'alf/probe01/clusters.depths.npy',
#  'alf/probe01/spikes.clusters.npy',
#  'alf/probe01/clusters.brainLocationAcronyms_ccf_2017.npy',
#  'alf/probe01/clusters.channels.npy',
#  'alf/probe01/clusters.peakToTrough.npy',
#  'alf/probe01/channels.brainLocationIds_ccf_2017.npy',
#  'alf/probe01/clusters.brainLocationIds_ccf_2017.npy',
#  'alf/probe01/clusters.waveforms.npy',
#  'alf/probe01/channels.mlapdv.npy',
#  'alf/probe01/spikes.samples.npy',
#  'alf/probe01/_kilosort_whitening.matrix.npy',
#  'alf/probe01/_phy_spikes_subset.channels.npy',
#  'alf/probe01/spikes.templates.npy',
#  'alf/probe01/templates.amps.npy',
#  'alf/probe01/clusters.mlapdv.npy',
#  'alf/probe01/templates.waveforms.npy',
#  'alf/probe01/spikes.times.npy',
#  'alf/probe01/spikes.depths.npy',
#  'alf/probe01/clusters.uuids.csv',
#  'alf/probe01/channels.rawInd.npy',
#  'alf/probe01/channels.localCoordinates.npy',
#  'alf/probe01/templates.waveformsChannels.npy',
#  'alf/probe01/clusters.waveformsChannels.npy',
#  'alf/probe01/_phy_spikes_subset.spikes.npy',
#  'alf/probe01/_phy_spikes_subset.waveforms.npy',
#  'alf/probe01/clusters.metrics.pqt',
#  'alf/#2022-01-28#/_ibl_leftCamera.dlc.pqt',
#  'alf/#2022-01-28#/leftCamera.ROIMotionEnergy.npy',
#  'alf/#2022-01-28#/bodyCamera.ROIMotionEnergy.npy',
#  'alf/#2022-01-28#/_ibl_bodyCamera.dlc.pqt',
#  'alf/#2022-01-28#/_ibl_rightCamera.dlc.pqt',
#  'alf/#2022-01-28#/rightCamera.ROIMotionEnergy.npy',
#  'raw_ephys_data/probe01/#2021-12-10#/_iblqc_ephysTimeRmsAP.rms.npy',
#  'alf/#2022-01-28#/bodyROIMotionEnergy.position.npy',
#  'alf/#2022-01-28#/rightROIMotionEnergy.position.npy',
#  'raw_ephys_data/probe01/#2021-12-10#/_iblqc_ephysTimeRmsAP.timestamps.npy',
#  'alf/#2022-01-28#/leftROIMotionEnergy.position.npy',
#  'alf/probe00/pykilosort/clusters.brainLocationAcronyms_ccf_2017.npy',
#  'alf/probe00/pykilosort/clusters.mlapdv.npy',
#  'alf/probe00/pykilosort/clusters.brainLocationIds_ccf_2017.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g1_t0.imec.ap.cbin',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g1_t0.imec.timestamps.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g1_t0.imec.sync.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g1_t0.imec.ap.ch',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g1_t0.imec.lf.ch',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g1_t0.imec.lf.meta',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g1_t0.imec.wiring.json',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g1_t0.imec.lf.cbin',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g1_t0.imec.ap.meta',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec.lf.meta',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec.lf.cbin',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec.sync.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec.lf.ch',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec.ap.ch',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec.ap.cbin',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec.timestamps.npy',
#  'raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec.ap.meta',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g4_t0.imec0.lf.meta',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g4_t0.imec0.lf.ch',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g4_t0.imec0.ap.meta',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g4_t0.imec0.timestamps.npy',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g4_t0.imec0.ap.ch',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g4_t0.imec0.sync.npy',
#  'raw_ephys_data/_spikeglx_ephysData_g4_t0.nidq.meta',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g4_t0.imec0.lf.cbin',
#  'raw_ephys_data/_spikeglx_ephysData_g4_t0.nidq.wiring.json',
#  'raw_ephys_data/_spikeglx_ephysData_g4_t0.nidq.cbin',
#  'raw_ephys_data/_spikeglx_ephysData_g4_t0.nidq.ch',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g4_t0.imec0.ap.cbin',
#  'raw_ephys_data/probe00/_spikeglx_ephysData_g4_t0.imec0.wiring.json']

# %%
eids, info = one.search(dataset='probes.description', task_protocol='_iblrig_tasks_ephysChoiceWorld6.4.2', details=True)

# %%
print(eids)
# Out:
# ['2bdf206a-820f-402f-920a-9e86cd5388a4', '8a3a0197-b40a-449f-be55-c00b23253bbf', '03d9a098-07bf-4765-88b7-85f8d8f620cc', '824cf03d-4012-4ab1-b499-c83a92c5589e', '51e53aff-1d5d-4182-a684-aba783d50ae5', 'c51f34d8-42f6-4c9c-bb5b-669fd9c42cd9', '0802ced5-33a3-405e-8336-b65ebc5cb07c', 'f140a2ec-fd49-4814-994a-fe3476f14e66', 'd2832a38-27f6-452d-91d6-af72d794136c', '88224abb-5746-431f-9c17-17d7ef806e6a', '72cb5550-43b4-4ef0-add5-e4adfdfb5e02', 'b22f694e-4a34-4142-ab9d-2556c3487086', '30c4e2ab-dffc-499d-aae4-e51d6b3218c2', 'ff96bfe1-d925-4553-94b5-bf8297adf259', '7af49c00-63dd-4fed-b2e0-1b3bd945b20b', '73918ae1-e4fd-4c18-b132-00cb555b1ad2', 'd0ea3148-948d-4817-94f8-dcaf2342bbbe', '0cad7ea8-8e6c-4ad1-a5c5-53fbb2df1a63', '781b35fd-e1f0-4d14-b2bb-95b7263082bb', 'd9f0c293-df4c-410a-846d-842e47c6b502', '3638d102-e8b6-4230-8742-e548cd87a949', 'c4432264-e1ae-446f-8a07-6280abade813', 'dac3a4c1-b666-4de0-87e8-8c514483cacf', '7cb81727-2097-4b52-b480-c89867b5b34c', '746d1902-fa59-4cab-b0aa-013be36060d5', '7691eeb3-715b-4571-8fda-6bb57aab8253', '54238fd6-d2d0-4408-b1a9-d19d24fd29ce', '56b57c38-2699-4091-90a8-aba35103155e', '4a45c8ba-db6f-4f11-9403-56e06a33dfa4', '4ecb5d24-f5cc-402c-be28-9d0f7cb14b3a', '754b74d5-7a06-4004-ae0c-72a10b6ed2e6', 'c7bd79c9-c47e-4ea5-aea3-74dda991b48e', '6f09ba7e-e3ce-44b0-932b-c003fb44fb89', 'd23a44ef-1402-4ed7-97f5-47e9a7a504d9']

# %%
for eid in eids:
  try:
    dat = one.load_dataset(eid, '*channels.brainLocationIds_ccf_2017.npy')
  except:
    print('this eid doesn\'t have brain loc acr: ', eid)
# Out:
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/churchlandlab_ucla/Subjects/UCLA037/2022-02-02/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 25.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/churchlandlab_ucla/Subjects/UCLA034/2022-01-25/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 28.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/churchlandlab_ucla/Subjects/UCLA014/2021-08-18/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 25.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/churchlandlab_ucla/Subjects/UCLA011/2021-07-20/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 21.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/angelakilab/Subjects/NYU-45/2021-07-19/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 22.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/angelakilab/Subjects/NYU-48/2021-06-28/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 22.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/mainenlab/Subjects/ZFM-02373/2021-06-23/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 23.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/angelakilab/Subjects/NYU-47/2021-06-21/003/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 21.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/wittenlab/Subjects/ibl_witten_29/2021-06-08/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 19.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/mainenlab/Subjects/ZFM-02372/2021-06-01/002/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 23.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/mainenlab/Subjects/ZFM-02369/2021-05-19/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 26.3kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/cortexlab/Subjects/KS055/2021-05-02/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 26.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/mainenlab/Subjects/ZFM-02370/2021-04-29/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 24.6kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/wittenlab/Subjects/ibl_witten_26/2021-01-27/002/alf/probe01/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 26.8kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/angelakilab/Subjects/NYU-37/2021-01-25/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 23.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/wittenlab/Subjects/ibl_witten_27/2021-01-21/001/alf/probe01/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 19.2kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/mainenlab/Subjects/ZFM-01936/2021-01-19/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 27.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/cortexlab/Subjects/KS045/2020-12-09/001/alf/probe01/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 27.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/cortexlab/Subjects/KS044/2020-12-09/001/alf/probe01/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 23.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/wittenlab/Subjects/ibl_witten_25/2020-12-07/002/alf/probe01/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 25.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/mrsicflogellab/Subjects/SWC_058/2020-12-07/001/alf/probe01/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 24.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/mainenlab/Subjects/ZFM-01576/2020-12-01/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 13.9kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_060/2020-11-24/001/alf/probe01/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 21.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/mrsicflogellab/Subjects/SWC_052/2020-10-22/001/alf/probe01/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 20.1kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/mainenlab/Subjects/ZFM-01592/2020-10-20/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 22.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/angelakilab/Subjects/NYU-30/2020-10-19/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/danlab/Subjects/DY_018/2020-10-15/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 24.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/mrsicflogellab/Subjects/SWC_054/2020-10-05/001/alf/probe01/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 28.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/danlab/Subjects/DY_020/2020-09-29/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 20.4kB/s]
# this eid doesn't have brain loc acr:  4ecb5d24-f5cc-402c-be28-9d0f7cb14b3a
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/angelakilab/Subjects/NYU-29/2020-09-21/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 28.4kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/zadorlab/Subjects/CSH_ZAD_029/2020-09-19/001/alf/probe01/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.12k/3.12k [00:00<00:00, 25.0kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-16/002/alf/probe01/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 32.5kB/s]
# /root/Downloads/ONE/openalyx.internationalbrainlab.org/danlab/Subjects/DY_016/2020-09-12/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 21.2kB/s]
